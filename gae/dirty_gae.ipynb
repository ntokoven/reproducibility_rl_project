# %% [markdown]
# https://datascience.stackexchange.com/questions/32480/how-does-generalised-advantage-estimation-work
# https://lilianweng.github.io/lil-log/2018/02/19/a-long-peek-into-reinforcement-learning.html#combining-td-and-mc-learning
# https://arxiv.org/pdf/1506.02438.pdf
# https://github.com/higgsfield/RL-Adventure-2
# http://www.breloff.com/DeepRL-OnlineGAE/
# https://arxiv.org/pdf/1804.02717.pdf
# https://ewrl.files.wordpress.com/2015/02/ewrl12_2015_submission_18.pdf
# https://github.com/Kaixhin/Dist-A3C
# https://github.com/Kaixhin/Dist-A3C/blob/master/client.py

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions

import matplotlib.pyplot as plt
from tqdm import tqdm_notebook as tqdm
import numpy as np
import gym

env_name = 'CartPole-v0'
#env_name = 'FrozenLake-v0'
env = gym.make(env_name)

#assert isinstance(env.observation_space, gym.spaces.Box)
#assert isinstance(env.action_space, gym.spaces.Discrete)

SEED = 43
init = True
model_path = ['actor_weights.pt', 'critic_weights.pt']
save = False
env.seed(SEED);
np.random.seed(SEED);
torch.manual_seed(SEED);

class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout = 0.25):
        super().__init__()

        self.fc_1 = nn.Linear(input_dim, hidden_dim)
        self.fc_2 = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        x = self.fc_1(x)
        x = self.dropout(x)
        x = F.relu(x)
        x = self.fc_2(x)
        return x

#INPUT_DIM = env.observation_space.shape[0]
if env_name == 'FrozenLake-v0':
    INPUT_DIM = env.observation_space.n
else:
    INPUT_DIM = env.observation_space.shape[0]
print(INPUT_DIM)
HIDDEN_DIM = 128
OUTPUT_DIM = env.action_space.n

actor = MLP(INPUT_DIM, HIDDEN_DIM, OUTPUT_DIM)
critic = MLP(INPUT_DIM, HIDDEN_DIM, 1)
# Out:
# 4

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.xavier_normal_(m.weight)
        m.bias.data.fill_(0)

actor.apply(init_weights)
critic.apply(init_weights)
if not init:
    actor.load_state_dict(torch.load(model_path[0]))
    critic.load_state_dict(torch.load(model_path[1]))

LEARNING_RATE = 0.01

actor_optimizer = optim.Adam(actor.parameters(), lr = LEARNING_RATE)
critic_optimizer = optim.Adam(critic.parameters(), lr = LEARNING_RATE)






def save_results(mean_return, std_return, timestamps, time_start, seed, env_name, init, name='gae'):
    run_dict = {'name': name, 
                'avg_ret': mean_return,
                'std_dev': std_return,
                'timestamps': timestamps,
                'time_start': time_start,
                'seed': seed,
                'env_name': env_name}
    if not init:
        filename = 'run_time_%s_%s_%s.pickle' % (name, seed, 'pretrained')
    else:
        filename = 'run_time_%s_%s.pickle' % (name, seed)
    with open(filename, 'wb') as handle:
        pickle.dump(run_dict, handle, protocol=pickle.HIGHEST_PROTOCOL)


def train(env, actor, critic, actor_optimizer, critic_optimizer, discount_factor, trace_decay, init):
    
    log_prob_actions_list = []
    values_list = []
    rewards = []
    done = False
    episode_reward = 0

    state = env.reset()
    n = 4
    step = 0
    while not done:
        if type(state) != torch.Tensor:
            state = torch.FloatTensor(state).unsqueeze(0)
        action_preds = actor(state)
        value_pred = critic(state)
        action_probs = F.softmax(action_preds, dim = -1)
        dist = distributions.Categorical(action_probs)
    
        action = dist.sample()
        
        log_prob_action = dist.log_prob(action)
        
        new_state, reward, done, _ = env.step(action.item())
        log_prob_actions_list.append(log_prob_action)
        values_list.append(value_pred)
        rewards.append(reward)
        #print(step, values[-n:], rewards[-n:])
        episode_reward += reward
        step += 1
        old_state = state
        state = new_state

        if step >= n:
            #print(len(log_prob_actions_list))
            log_prob_actions = torch.cat(log_prob_actions_list[-n:])
            #print('Torch: ',log_prob_actions.size())

            #values = [value_pred, new_value_pred]
            values = torch.cat(values_list).squeeze(-1)
            returns = calculate_returns(rewards[-n:], values[-n:], discount_factor, n)
            advantages = calculate_advantages(rewards[-n:], values[-n:], discount_factor, trace_decay)
            #print('Adbantages', advantages)
            policy_loss, value_loss = update_policy(advantages, log_prob_actions, returns, values, actor_optimizer, critic_optimizer, init)
    return policy_loss, value_loss, episode_reward

def calculate_returns(rewards, values, discount_factor, n = 1, normalize = True):
    
    returns = []
    R = 0
    #print('Here:', len(rewards[-n:]))
    #print('There: ', values)
    #print(reversed(rewards))
    r = rewards[-n]
    #print(r)
    #for i in range(n):
    #    r += discount_factor**(i+1) * values[-(n-i)]
    for r in reversed(rewards):
        R = r + R * discount_factor
        returns.insert(0, R)
    returns = torch.tensor(r)
    #print(returns)
    if not normalize:
        
        returns = (returns - returns.mean()) / returns.std()
    #print(returns.item())
    return returns

def calculate_advantages(rewards, values, discount_factor, trace_decay, n=1, normalize = True):
    
    advantages = []
    advantage = 0
    next_value = 0
    #print('AA"AAA"', rewards, values)
    #td_error = rewards[-n] + v[-n] * discount_factor - v[-(n+1)]
    for r, v in zip(reversed(rewards), reversed(values)):
        #print('STEP CALC')
        td_error = r + next_value * discount_factor - v
        advantage = td_error + advantage * discount_factor * trace_decay
        next_value = v
        advantages.insert(0, advantage)
    advantages = torch.tensor(advantages)
    
    if normalize:
        advantages = (advantages - advantages.mean()) / advantages.std()
        
    return advantages

def update_policy(advantages, log_prob_actions, returns, values, actor_optimizer, critic_optimizer, init):
        
    advantages = advantages.detach()
    returns = returns.detach()
    policy_loss = - (advantages * log_prob_actions).mean()
    
    value_loss = F.smooth_l1_loss(returns, values).mean()
        
    actor_optimizer.zero_grad()
    critic_optimizer.zero_grad()
    
    policy_loss.backward(retain_graph=True)
    value_loss.backward(retain_graph=True)
    if init:
        #print('!! Doing Policy update !!')
        actor_optimizer.step()
        critic_optimizer.step()
    
    return policy_loss.item(), value_loss.item()

import time
import pickle

MAX_EPISODES = 500
DISCOUNT_FACTOR = 1#0.99
TRACE_DECAY = 0.97
N_TRIALS = 25
REWARD_THRESHOLD = 475
PRINT_EVERY = 10

episode_rewards = []
timestamps = []
time_start = time.time()
avg_ret = []
std_dev = []
for episode in range(1, MAX_EPISODES+1):
    
    policy_loss, value_loss, episode_reward = train(env, actor, critic, actor_optimizer, critic_optimizer, DISCOUNT_FACTOR, TRACE_DECAY, init)

    episode_rewards.append(episode_reward)
    #mean_trial_rewards = np.mean(episode_rewards[-N_TRIALS:])
    #std_trial_rewards = np.std(episode_rewards[-N_TRIALS:])
    
    timestamps.append(time.time())
    avg_ret.append(mean_trial_rewards)
    std_dev.append(std_trial_rewards)
    
    if episode % PRINT_EVERY == 0:
    
        print(f'| Episode: {episode:4} | Episode Reward: {episode_reward:6.2f} ')
    
    if mean_trial_rewards >= REWARD_THRESHOLD:
        
        print(f'Reached reward threshold in {episode} episodes')
        
        break

        
save_results(avg_ret, std_dev, timestamps, time_start, SEED, env_name, init)
if save == True:
    torch.save(actor.state_dict(), 'actor_weights.pt')
    torch.save(critic.state_dict(), 'critic_weights.pt')
# Out:
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([4])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([5])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([6])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([7])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([9])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([10])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([11])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([13])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([14])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([15])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([16])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([17])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# /Users/ntokoven/miniconda3/envs/rl2019/lib/python3.7/site-packages/ipykernel_launcher.py:132: UserWarning: Using a target size (torch.Size([121])) that is different to the input size (torch.Size([])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
# | Episode:   30 | Episode Reward:   9.00
# | Episode:   40 | Episode Reward:   9.00
# | Episode:   50 | Episode Reward:   8.00
# | Episode:   60 | Episode Reward:  10.00
# | Episode:   70 | Episode Reward:  10.00
# | Episode:   80 | Episode Reward:   9.00
# | Episode:   90 | Episode Reward:  10.00
# | Episode:  100 | Episode Reward:   9.00
# | Episode:  110 | Episode Reward:   9.00
# | Episode:  120 | Episode Reward:   9.00
# | Episode:  130 | Episode Reward:   9.00
# | Episode:  140 | Episode Reward:   8.00
# | Episode:  150 | Episode Reward:   9.00
# | Episode:  160 | Episode Reward:   9.00
# | Episode:  170 | Episode Reward:   9.00
# | Episode:  180 | Episode Reward:   9.00
# | Episode:  190 | Episode Reward:  10.00
# | Episode:  200 | Episode Reward:   9.00
# | Episode:  210 | Episode Reward:   9.00
# | Episode:  220 | Episode Reward:   8.00
# | Episode:  230 | Episode Reward:   9.00
# | Episode:  240 | Episode Reward:   8.00
# | Episode:  250 | Episode Reward:  10.00
# | Episode:  260 | Episode Reward:   9.00
# | Episode:  270 | Episode Reward:   9.00
# | Episode:  280 | Episode Reward:   9.00
# | Episode:  290 | Episode Reward:  10.00
# | Episode:  300 | Episode Reward:   9.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-142-b2ff86b96e89> in <module>
#     161 for episode in range(1, MAX_EPISODES+1):
#     162
# --> 163     policy_loss, value_loss, episode_reward = train(env, actor, critic, actor_optimizer, critic_optimizer, DISCOUNT_FACTOR, TRACE_DECAY, init)
#     164
#     165     episode_rewards.append(episode_reward)
#
# <ipython-input-142-b2ff86b96e89> in train(env, actor, critic, actor_optimizer, critic_optimizer, discount_factor, trace_decay, init)
#      79             advantages = calculate_advantages(rewards[-n:], values[-n:], discount_factor, trace_decay)
#      80             #print('Adbantages', advantages)
# ---> 81             policy_loss, value_loss = update_policy(advantages, log_prob_actions, returns, values, actor_optimizer, critic_optimizer, init)
#      82     return policy_loss, value_loss, episode_reward
#      83
#
# <ipython-input-142-b2ff86b96e89> in update_policy(advantages, log_prob_actions, returns, values, actor_optimizer, critic_optimizer, init)
#     136
#     137     policy_loss.backward(retain_graph=True)
# --> 138     value_loss.backward(retain_graph=True)
#     139     if init:
#     140         #print('!! Doing Policy update !!')
#
# ~/miniconda3/envs/rl2019/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     116                 products. Defaults to ``False``.
#     117         """
# --> 118         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     119
#     120     def register_hook(self, hook):
#
# ~/miniconda3/envs/rl2019/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      91     Variable._execution_engine.run_backward(
#      92         tensors, grad_tensors, retain_graph, create_graph,
# ---> 93         allow_unreachable=True)  # allow_unreachable flag
#      94
#      95
#
# KeyboardInterrupt:

# %%
plt.figure(figsize=(12,8))
plt.plot(episode_rewards)
plt.xlabel('Episode', fontsize=20)
plt.ylabel('Reward', fontsize=20)
plt.hlines(REWARD_THRESHOLD, 0, len(episode_rewards), color='r')
plt.grid()
